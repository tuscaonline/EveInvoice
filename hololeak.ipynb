# %%
from eve_invoice import holoDirs
from eve_invoice.hololeak import updateHololeakData
from rich import inspect
import json

# %%
updateHololeakData()
# Out:
# fichier identique

# %%
with (holoDirs / "blueprints.json").open('r') as fd :
    blueprint = json.load(fd)

# %%
blueprint["57490"]
# Out:
# {'activities': {'reaction': {'skills': [{'typeID': 45746, 'level': 1}],
#    'materials': [{'typeID': 4246, 'quantity': 5},
#     {'typeID': 16633, 'quantity': 100},
#     {'typeID': 16635, 'quantity': 100}],
#    'products': [{'typeID': 57453, 'quantity': 200}],
#    'time': 10800}},
#  'blueprintTypeID': 57490,
#  'maxProductionLimit': 1000}

# %%
from eve_invoice.hololeak_types import HoloBlueprint
inspect(HoloBlueprint(**blueprints["16228"]))
# Out:
# ╭────────────────────────────── <class 'eve_invoice.hololeak_types.HoloBlueprint'> ───────────────────────────────╮
# │ HoloBlueprint(activities: str, blueprintTypeID: int, maxProductionLimit: int)                                   │
# │                                                                                                                 │
# │ ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────╮ │
# │ │ HoloBlueprint(                                                                                              │ │
# │ │ │   activities={                                                                                            │ │
# │ │ │   │   'research_material': {'time': 5250},                                                                │ │
# │ │ │   │   'research_time': {'time': 5250},                                                                    │ │
# ...

# %%
blueprints["16228"]['activities']['research_material']
# Out:
# {'time': 5250}

# %%
blueprints["22447"]
# Out:
# {'activities': {'research_material': {'skills': [{'typeID': 3409, 'level': 5},
#     {'typeID': 11452, 'level': 1},
#     {'typeID': 11454, 'level': 1}],
#    'materials': [{'typeID': 9836, 'quantity': 30},
#     {'typeID': 3814, 'quantity': 48},
#     {'typeID': 11463, 'quantity': 8}],
#    'time': 105000},
#   'research_time': {'skills': [{'typeID': 3403, 'level': 5},
#     {'typeID': 11452, 'level': 1},
#     {'typeID': 11454, 'level': 1}],
#    'materials': [{'typeID': 9836, 'quantity': 30},
#     {'typeID': 3814, 'quantity': 48},
#     {'typeID': 11463, 'quantity': 8}],
#    'time': 105000},
#   'manufacturing': {'skills': [{'typeID': 3380, 'level': 5},
#     {'typeID': 3397, 'level': 1},
#     {'typeID': 11452, 'level': 1},
#     {'typeID': 11454, 'level': 1}],
#    'materials': [{'typeID': 11552, 'quantity': 900},
#     {'typeID': 11399, 'quantity': 300},
#     {'typeID': 11533, 'quantity': 120},
#     {'typeID': 11534, 'quantity': 495},
# ...
